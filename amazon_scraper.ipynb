# %%
from dputils.scrape import Scraper, Tag

# %%
def get_data(query, page=1):
    scraper=Scraper('https://www.amazon.com/s?k={query}&page={page}')
    print (scraper.soup.title)
    target=Tag(cls='s-main-slot s-result-list s-search-results sg-row')
    items=Tag(cls='s-result-item')
    brand=Tag('h5')
    title=Tag('h2')
    price=Tag('span',cls='a-price-whole')
    rating=Tag('span', cls='a-size-base')
    oprice=Tag('span', cls='a-offscreen')
    return scraper.get_all(target,items, brand=brand, title=title, price=price, rating=rating, oprice=oprice)

# %%
query='warch'
page=1
all_data=[]
for i in range(1,11):
    print(f'fetching page{i} data')
    data= get_data(query, i)
    if len(data)==0:
        print('no more data')
        break
    all_data.extend(data)
all_data
# Out:
# fetching page1 data
# <title>Amazon.com : {query}</title>
# fetching page2 data
# <title>Amazon.com : {query}</title>
# fetching page3 data
# <title>Amazon.com : {query}</title>
# fetching page4 data
# <title>Amazon.com : {query}</title>
# fetching page5 data
# <title>Amazon.com : {query}</title>
# fetching page6 data
# <title>Amazon.com : {query}</title>
# fetching page7 data
# <title>Amazon.com : {query}</title>
# fetching page8 data
# <title>Amazon.com : {query}</title>
# fetching page9 data
# <title>Amazon.com : {query}</title>
# fetching page10 data
# <title>Amazon.com : {query}</title>
# [{'brand': None,
#   'title': None,
#   'price': None,
#   'rating': 'Price and other details may vary based on product size and color.',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Quaker Queries for All Seasons  ',
#   'price': '9.',
#   'rating': 'by ',
#   'oprice': '$9.99'},
#  {'brand': None,
#   'title': "Cosmic Queries: StarTalk's Guide to Who We Are, How We Got Here, and Where We're Going  ",
#   'price': '22.',
#   'rating': 'by ',
#   'oprice': '$22.49'},
#  {'brand': None,
#   'title': 'SQL Queries for Mere Mortals: A Hands-On Guide to Data Manipulation in SQL  ',
#   'price': '40.',
#   'rating': '4.5',
#   'oprice': '$40.99'},
#  {'brand': None,
#   'title': 'Old Country  ',
#   'price': '0.',
#   'rating': 'by ',
#   'oprice': '$0.00'},
#  {'brand': None,
#   'title': 'EXCEL 2022 POWER PIVOT & POWER QUERY FOR BEGINNERS: COMPLETE STEP-BY-STEP PRACTICAL GUIDE WITH EXAMPLES FOR MASTERING EXCEL POWER PIVOT AND POWER ... IMPORTATION, TRANSFORMATION, AND MODELLING  ',
#   'price': '12.',
#   'rating': '3.5',
#   'oprice': '$12.99'},
#  {'brand': None,
#   'title': 'SQL Cookbook: Query Solutions and Techniques for All SQL Users  ',
#   'price': '24.',
#   'rating': 'by ',
#   'oprice': '$24.96'},
#  {'brand': None,
#   'title': 'The Failsafe Query: The high risk search for a spy legacy (Failsafe Thrillers)  ',
#   'price': '9.',
#   'rating': '4.0',
#   'oprice': '$9.08'},
#  {'brand': None,
#   'title': 'Query: Everything You Need To Get Started, Get Noticed, and Get Signed  ',
#   'price': '3.',
#   'rating': 'by ',
#   'oprice': '$3.99'},
#  {'brand': None,
#   'title': 'Quarrys, Queries  ',
#   'price': None,
#   'rating': 'by ',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Easy Sim USSD, Query, Recharge  ',
#   'price': None,
#   'rating': 'Nov 13, 2016',
#   'oprice': None},
#  {'brand': None,
#   'title': 'The Big Book Of SQL Queries: 250+ SQL Practice Queries (SQL Series)  ',
#   'price': '24.',
#   'rating': '4.6',
#   'oprice': '$24.95'},
#  {'brand': None,
#   'title': 'SQL Server 2017 Query Performance Tuning: Troubleshoot and Optimize Query Performance  ',
#   'price': '38.',
#   'rating': 'by ',
#   'oprice': '$38.03'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': 'Jackery Portable Power Station Explorer 240, 240Wh Backup Lithium Battery, 110V/200W Pure Sine Wave AC Outlet, Solar Generator (Solar Panel Not Included) for Outdoors Camping Travel Hunting Emergency  ',
#   'price': None,
#   'rating': '4.7',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Query  ',
#   'price': '0.',
#   'rating': '2020',
#   'oprice': '$0.99'},
#  {'brand': None,
#   'title': 'Milwaukee 48-11-1880 M18 REDLITHIUM HIGH OUTPUT 18v 8.0 Ah Lithium-Ion Battery Pack  ',
#   'price': '118.',
#   'rating': '4.8',
#   'oprice': '$118.00'},
#  {'brand': None,
#   'title': 'Betsey Johnson Woven Mixed Multi-Colored Bead Flower Heart Illusion Necklace  ',
#   'price': '48.',
#   'rating': '4.4',
#   'oprice': '$48.00'},
#  {'brand': None,
#   'title': 'DEWALT 20V MAX Battery, 2 Ah and 4 Ah, 4-Pack, Fuel Gauge LED Charge Indicators(DCB324-4)  ',
#   'price': '172.',
#   'rating': '4.8',
#   'oprice': '$172.99'},
#  {'brand': None,
#   'title': 'Thorne Quercetin Phytosome - Exclusive Phytosome Complex for Immune Health, Respiratory Support, and Seasonal Allergy Relief - 60 Capsules  ',
#   'price': '37.',
#   'rating': '60 Count (Pack of 1)',
#   'oprice': '$37.98'},
#  {'brand': None,
#   'title': 'Live Nude Girls Unite!  ',
#   'price': '3.',
#   'rating': '2000',
#   'oprice': '$3.99'},
#  {'brand': None,
#   'title': 'Milwaukee M18 48-11-1850 5.0 AH Batteries 5.0 18V 48-11-1852 (2 pack)  ',
#   'price': None,
#   'rating': '4.7',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Energizer 2032 Batteries, Lithium CR2032 Watch Battery, 6 Count  ',
#   'price': None,
#   'rating': '6 Count (Pack of 1)',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Adobe Acrobat Professional DC | Create, edit and sign PDF documents | 1-month Subscription with auto-renewal, PC/Mac  ',
#   'price': '24.',
#   'rating': '3.9',
#   'oprice': '$24.99'},
#  {'brand': None,
#   'title': 'DEWALT 20V MAX XR Battery, Lithium Ion, 5.0Ah (DCB205)  ',
#   'price': '70.',
#   'rating': '4.7',
#   'oprice': '$70.95'},
#  {'brand': None,
#   'title': 'NOW Supplements, Quercetin with Bromelain, Balanced Immune System*, 120 Veg Capsules  ',
#   'price': '15.',
#   'rating': '4.7',
#   'oprice': '$15.11'},
#  {'brand': None,
#   'title': 'Amazing Formulas Quercetin 500mg 120 Veggie Capsules Supplement - Non-GMO - Gluten Free - Supports Overall Health & Well Being  ',
#   'price': '19.',
#   'rating': '120 Count (Pack of 1)',
#   'oprice': '$19.99'},
#  {'brand': None,
#   'title': 'Jarrow Formulas Quercetin 500 mg - Supports Antioxidant Status, Cardiovascular Health & Immune Health - Dietary Supplement - 100 Servings (Veggie Caps) (Packaging May Vary)  ',
#   'price': '22.',
#   'rating': '100 Count (Pack of 1)',
#   'oprice': '$22.77'},
#  {'brand': None,
#   'title': 'Creating a Query with Microsoft Access 2007  ',
#   'price': None,
#   'rating': '2017',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Milwaukee 48-11-1850 M18 Redlithium 5.0Ah Bat Pack  ',
#   'price': '61.',
#   'rating': '4.8',
#   'oprice': '$61.99'},
#  {'brand': None,
#   'title': 'Learn PowerShell in a Month of Lunches, Fourth Edition: Covers Windows, Linux, and macOS  ',
#   'price': '35.',
#   'rating': 'by ',
#   'oprice': '$35.99'},
#  {'brand': None,
#   'title': 'Energizer 2032 Batteries, Lithium CR2032 Watch Battery, 4 Count  ',
#   'price': None,
#   'rating': '4 Count (Pack of 1)',
#   'oprice': None},
#  {'brand': None,
#   'title': 'NatureBell Quercetin 1000mg Per Serving | 240 Capsules, Ultra Strength Quercetin Supplement | Bioflavonoids for Healthy Immune Support, Third Party Tested, Non-GMO & No Gluten  ',
#   'price': '26.',
#   'rating': '240 Count (Pack of 1)',
#   'oprice': '$26.95'},
#  {'brand': None,
#   'title': 'Zinc Quercetin 120 Vegetarian Capsules  ',
#   'price': '24.',
#   'rating': '120 Count (Pack of 1)',
#   'oprice': '$24.95'},
#  {'brand': None,
#   'title': 'SOLARAY Quercetin 500 mg, Supports Sinus, Respiratory, Immune Function & Normal, Healthy Uric Acid Levels, 90 VegCaps  ',
#   'price': '23.',
#   'rating': '90 Count (Pack of 1)',
#   'oprice': '$23.39'},
#  {'brand': None,
#   'title': 'SVP‑916 100‑130VAC Adjustable Over and Under Voltage Protector, Delay Reset Protector, with Reset Mode Selection, Fault Query and Factory Reset Function  ',
#   'price': '17.',
#   'rating': '4.5',
#   'oprice': '$17.20'},
#  {'brand': None,
#   'title': 'Query Craft: The Writer-in-the-Know Guide to Getting Your Manuscript Requested  ',
#   'price': '11.',
#   'rating': 'by ',
#   'oprice': '$11.99'},
#  {'brand': None,
#   'title': "Doctor's Best Quercetin Bromelain, Immunity Support, Heart, Joint & Healthy Respiratory System, Non-GMO, Vegan, Gluten Free, Soy Free,180 VC  ",
#   'price': '21.',
#   'rating': '180 Count (Pack of 1)',
#   'oprice': '$21.68'},
#  {'brand': None,
#   'title': 'Cloud Computing Simplified: Explore Application of Cloud, Cloud Deployment Models, Service Models and Mobile Cloud Computing (English Edition)  ',
#   'price': '19.',
#   'rating': 'by ',
#   'oprice': '$19.95'},
#  {'brand': None,
#   'title': 'Hands-on Cloud Analytics with Microsoft Azure Stack: Transform Your Data to Derive Powerful Insights Using Microsoft Azure (English Edition)  ',
#   'price': '10.',
#   'rating': 'by ',
#   'oprice': '$10.80'},
#  {'brand': None,
#   'title': 'Learn SQL in a weekend: The definitive guide for creating and querying databases  ',
#   'price': '8.',
#   'rating': '4.4',
#   'oprice': '$8.99'},
#  {'brand': None,
#   'title': 'Hands-on Pipeline as Code with Jenkins: CI/CD Implementation for Mobile, Web, and Hybrid Applications Using Declarative Pipeline in Jenkins (English Edition)  ',
#   'price': '29.',
#   'rating': 'by ',
#   'oprice': '$29.95'},
#  {'brand': None,
#   'title': '8.4 - 2. Working with Media Queries  ',
#   'price': None,
#   'rating': '2017',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Duracell CR2032 3V Lithium Battery, Child Safety Features, 6 Count Pack, Lithium Coin Battery for Key Fob, Car Remote, Glucose Monitor, CR Lithium 3 Volt Cell  ',
#   'price': None,
#   'rating': '6 Count (Pack of 1)',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Master Your Data with Power Query in Excel and Power BI: Leveraging Power Query to Get & Transform Your Task Flow  ',
#   'price': '19.',
#   'rating': 'by ',
#   'oprice': '$19.39'},
#  {'brand': None,
#   'title': 'Excel Power Pivot & Power Query For Dummies  ',
#   'price': '25.',
#   'rating': 'by ',
#   'oprice': '$25.49'},
#  {'brand': None,
#   'title': 'Optima Batteries 8004-003 34/78 RedTop Starting Battery  ',
#   'price': None,
#   'rating': '4.5',
#   'oprice': None},
#  {'brand': None,
#   'title': 'The Ultimate Guide to Power Query: A Step-By-Step Guide on Using Power Query Effectively for Data Transformation  ',
#   'price': '12.',
#   'rating': 'by ',
#   'oprice': '$12.00'},
#  {'brand': None,
#   'title': 'Starry Messenger: Cosmic Perspectives on Civilization  ',
#   'price': '0.',
#   'rating': 'by ',
#   'oprice': '$0.00'},
#  {'brand': None,
#   'title': 'Quercetin | Sugar Free | Liquid Quercetin 500mg Immune Support for Adults & Kids | Inflammation Support Supplement | Immune Defense | Cellular Health | Vegan | Non-GMO | Gluten Free | 4 Fl Oz  ',
#   'price': '20.',
#   'rating': '4 Fl Oz (Pack of 1)',
#   'oprice': '$20.25'},
#  {'brand': None,
#   'title': 'SQL Server 2022 Query Performance Tuning: Troubleshoot and Optimize Query Performance  ',
#   'price': '54.',
#   'rating': 'by ',
#   'oprice': '$54.64'},
#  {'brand': None,
#   'title': 'Solgar Quercetin Complex with Ester-C Plus, 100 Vegetable Capsules - Supports Immune Health, Antioxidant - Gentle on the Stomach Vitamin C - Non-GMO, Vegan, Gluten / Dairy Free - 50 Servings  ',
#   'price': None,
#   'rating': '100 Count (Pack of 1)',
#   'oprice': None},
#  {'brand': None,
#   'title': 'SQL Queries 2012 Joes 2 Pros 5 Volume (DVD) Certification Training Tutorial for Microsoft Exam 70-461  ',
#   'price': None,
#   'rating': 'No reviews',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Collect, Combine, and Transform Data Using Power Query in Excel and Power BI (Business Skills)  ',
#   'price': '36.',
#   'rating': '4.6',
#   'oprice': '$36.53'},
#  {'brand': None,
#   'title': 'Amazon Basics 4 Pack CR2032 3 Volt Lithium Coin Cell Battery  ',
#   'price': None,
#   'rating': '4.7',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Hands-on Site Reliability Engineering: Build Capability to Design, Deploy, Monitor, and Sustain Enterprise Software Systems at Scale (English Edition)  ',
#   'price': '29.',
#   'rating': 'by ',
#   'oprice': '$29.95'},
#  {'brand': None,
#   'title': 'My Inner Sanctuary Journal  ',
#   'price': '9.',
#   'rating': 'by ',
#   'oprice': '$9.99'},
#  {'brand': None,
#   'title': 'Cloud Computing Using Salesforce: Build and Customize Applications for your business using the Salesforce Platform (English Edition)  ',
#   'price': '24.',
#   'rating': 'by ',
#   'oprice': '$24.95'},
#  {'brand': None,
#   'title': "Modern Oracle Enterprise Architecture: Discover Oracle's Hidden Gems for Next Generation Database and Application Migrations (English Edition)  ",
#   'price': '6.',
#   'rating': 'by ',
#   'oprice': '$6.70'},
#  {'brand': None,
#   'title': 'Mastering Azure Kubernetes Service (AKS): Rapidly Build and Scale Your Containerized Applications with Microsoft Azure Kubernetes Service (English Edition)  ',
#   'price': '29.',
#   'rating': 'by ',
#   'oprice': '$29.95'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': ' or ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': 'Price and other details may vary based on product size and color.',
#   'oprice': None},
#  {'brand': None,
#   'title': "Cosmic Queries: StarTalk's Guide to Who We Are, How We Got Here, and Where We're Going  ",
#   'price': '22.',
#   'rating': 'by ',
#   'oprice': '$22.49'},
#  {'brand': None,
#   'title': 'Quaker Queries for All Seasons  ',
#   'price': '9.',
#   'rating': 'by ',
#   'oprice': '$9.99'},
#  {'brand': None,
#   'title': 'SQL Queries for Mere Mortals: A Hands-On Guide to Data Manipulation in SQL  ',
#   'price': '40.',
#   'rating': '4.5',
#   'oprice': '$40.99'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': 'Old Country  ',
#   'price': '0.',
#   'rating': 'by ',
#   'oprice': '$0.00'},
#  {'brand': None,
#   'title': 'EXCEL 2022 POWER PIVOT & POWER QUERY FOR BEGINNERS: COMPLETE STEP-BY-STEP PRACTICAL GUIDE WITH EXAMPLES FOR MASTERING EXCEL POWER PIVOT AND POWER ... IMPORTATION, TRANSFORMATION, AND MODELLING  ',
#   'price': '12.',
#   'rating': '3.5',
#   'oprice': '$12.99'},
#  {'brand': None,
#   'title': 'SQL Cookbook: Query Solutions and Techniques for All SQL Users  ',
#   'price': '24.',
#   'rating': 'by ',
#   'oprice': '$24.96'},
#  {'brand': None,
#   'title': 'Query: Everything You Need To Get Started, Get Noticed, and Get Signed  ',
#   'price': '3.',
#   'rating': 'by ',
#   'oprice': '$3.99'},
#  {'brand': None,
#   'title': 'The Failsafe Query: The high risk search for a spy legacy (Failsafe Thrillers)  ',
#   'price': '9.',
#   'rating': '4.0',
#   'oprice': '$9.08'},
#  {'brand': None,
#   'title': 'Quarrys, Queries  ',
#   'price': None,
#   'rating': 'by ',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Easy Sim USSD, Query, Recharge  ',
#   'price': None,
#   'rating': 'Nov 13, 2016',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': 'The Big Book Of SQL Queries: 250+ SQL Practice Queries (SQL Series)  ',
#   'price': '24.',
#   'rating': '4.6',
#   'oprice': '$24.95'},
#  {'brand': None,
#   'title': 'Query Craft: The Writer-in-the-Know Guide to Getting Your Manuscript Requested  ',
#   'price': '11.',
#   'rating': 'by ',
#   'oprice': '$11.99'},
#  {'brand': None,
#   'title': 'Jackery Portable Power Station Explorer 240, 240Wh Backup Lithium Battery, 110V/200W Pure Sine Wave AC Outlet, Solar Generator (Solar Panel Not Included) for Outdoors Camping Travel Hunting Emergency  ',
#   'price': None,
#   'rating': '4.7',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Query  ',
#   'price': '0.',
#   'rating': '2020',
#   'oprice': '$0.99'},
#  {'brand': None,
#   'title': 'Milwaukee 48-11-1880 M18 REDLITHIUM HIGH OUTPUT 18v 8.0 Ah Lithium-Ion Battery Pack  ',
#   'price': '118.',
#   'rating': '4.8',
#   'oprice': '$118.00'},
#  {'brand': None,
#   'title': 'Betsey Johnson Woven Mixed Multi-Colored Bead Flower Heart Illusion Necklace  ',
#   'price': '48.',
#   'rating': '4.4',
#   'oprice': '$48.00'},
#  {'brand': None,
#   'title': 'DEWALT 20V MAX Battery, 2 Ah and 4 Ah, 4-Pack, Fuel Gauge LED Charge Indicators(DCB324-4)  ',
#   'price': '172.',
#   'rating': '4.8',
#   'oprice': '$172.99'},
#  {'brand': None,
#   'title': 'Thorne Quercetin Phytosome - Exclusive Phytosome Complex for Immune Health, Respiratory Support, and Seasonal Allergy Relief - 60 Capsules  ',
#   'price': '37.',
#   'rating': '60 Count (Pack of 1)',
#   'oprice': '$37.98'},
#  {'brand': None,
#   'title': 'Live Nude Girls Unite!  ',
#   'price': '3.',
#   'rating': '2000',
#   'oprice': '$3.99'},
#  {'brand': None,
#   'title': 'Energizer 2032 Batteries, Lithium CR2032 Watch Battery, 6 Count  ',
#   'price': None,
#   'rating': '6 Count (Pack of 1)',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Milwaukee M18 48-11-1850 5.0 AH Batteries 5.0 18V 48-11-1852 (2 pack)  ',
#   'price': None,
#   'rating': '4.7',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Adobe Acrobat Professional DC | Create, edit and sign PDF documents | 1-month Subscription with auto-renewal, PC/Mac  ',
#   'price': '24.',
#   'rating': '3.9',
#   'oprice': '$24.99'},
#  {'brand': None,
#   'title': 'DEWALT 20V MAX XR Battery, Lithium Ion, 5.0Ah (DCB205)  ',
#   'price': '70.',
#   'rating': '4.7',
#   'oprice': '$70.95'},
#  {'brand': None,
#   'title': 'NOW Supplements, Quercetin with Bromelain, Balanced Immune System*, 120 Veg Capsules  ',
#   'price': '15.',
#   'rating': '4.7',
#   'oprice': '$15.11'},
#  {'brand': None,
#   'title': 'Amazing Formulas Quercetin 500mg 120 Veggie Capsules Supplement - Non-GMO - Gluten Free - Supports Overall Health & Well Being  ',
#   'price': '19.',
#   'rating': '120 Count (Pack of 1)',
#   'oprice': '$19.99'},
#  {'brand': None,
#   'title': 'Jarrow Formulas Quercetin 500 mg - Supports Antioxidant Status, Cardiovascular Health & Immune Health - Dietary Supplement - 100 Servings (Veggie Caps) (Packaging May Vary)  ',
#   'price': '22.',
#   'rating': '100 Count (Pack of 1)',
#   'oprice': '$22.77'},
#  {'brand': None,
#   'title': 'Creating a Query with Microsoft Access 2007  ',
#   'price': None,
#   'rating': '2017',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Energizer 2032 Batteries, Lithium CR2032 Watch Battery, 4 Count  ',
#   'price': None,
#   'rating': '4 Count (Pack of 1)',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Learn PowerShell in a Month of Lunches, Fourth Edition: Covers Windows, Linux, and macOS  ',
#   'price': '35.',
#   'rating': 'by ',
#   'oprice': '$35.99'},
#  {'brand': None,
#   'title': 'Milwaukee 48-11-1850 M18 Redlithium 5.0Ah Bat Pack  ',
#   'price': '61.',
#   'rating': '4.8',
#   'oprice': '$61.99'},
#  {'brand': None,
#   'title': 'NatureBell Quercetin 1000mg Per Serving | 240 Capsules, Ultra Strength Quercetin Supplement | Bioflavonoids for Healthy Immune Support, Third Party Tested, Non-GMO & No Gluten  ',
#   'price': '26.',
#   'rating': '240 Count (Pack of 1)',
#   'oprice': '$26.95'},
#  {'brand': None,
#   'title': 'Zinc Quercetin 120 Vegetarian Capsules  ',
#   'price': '24.',
#   'rating': '120 Count (Pack of 1)',
#   'oprice': '$24.95'},
#  {'brand': None,
#   'title': 'SOLARAY Quercetin 500 mg, Supports Sinus, Respiratory, Immune Function & Normal, Healthy Uric Acid Levels, 90 VegCaps  ',
#   'price': '23.',
#   'rating': '90 Count (Pack of 1)',
#   'oprice': '$23.39'},
#  {'brand': None,
#   'title': 'SVP‑916 100‑130VAC Adjustable Over and Under Voltage Protector, Delay Reset Protector, with Reset Mode Selection, Fault Query and Factory Reset Function  ',
#   'price': '17.',
#   'rating': '4.5',
#   'oprice': '$17.20'},
#  {'brand': None,
#   'title': 'SQL Server 2017 Query Performance Tuning: Troubleshoot and Optimize Query Performance  ',
#   'price': '38.',
#   'rating': 'by ',
#   'oprice': '$38.03'},
#  {'brand': None,
#   'title': '8.4 - 2. Working with Media Queries  ',
#   'price': None,
#   'rating': '2017',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Cloud Computing Simplified: Explore Application of Cloud, Cloud Deployment Models, Service Models and Mobile Cloud Computing (English Edition)  ',
#   'price': '19.',
#   'rating': 'by ',
#   'oprice': '$19.95'},
#  {'brand': None,
#   'title': 'Hands-on Cloud Analytics with Microsoft Azure Stack: Transform Your Data to Derive Powerful Insights Using Microsoft Azure (English Edition)  ',
#   'price': '10.',
#   'rating': 'by ',
#   'oprice': '$10.80'},
#  {'brand': None,
#   'title': 'Learn SQL in a weekend: The definitive guide for creating and querying databases  ',
#   'price': '8.',
#   'rating': '4.4',
#   'oprice': '$8.99'},
#  {'brand': None,
#   'title': 'Hands-on Pipeline as Code with Jenkins: CI/CD Implementation for Mobile, Web, and Hybrid Applications Using Declarative Pipeline in Jenkins (English Edition)  ',
#   'price': '29.',
#   'rating': 'by ',
#   'oprice': '$29.95'},
#  {'brand': None,
#   'title': "Doctor's Best Quercetin Bromelain, Immunity Support, Heart, Joint & Healthy Respiratory System, Non-GMO, Vegan, Gluten Free, Soy Free,180 VC  ",
#   'price': '21.',
#   'rating': '180 Count (Pack of 1)',
#   'oprice': '$21.68'},
#  {'brand': None,
#   'title': 'Duracell CR2032 3V Lithium Battery, Child Safety Features, 6 Count Pack, Lithium Coin Battery for Key Fob, Car Remote, Glucose Monitor, CR Lithium 3 Volt Cell  ',
#   'price': None,
#   'rating': '6 Count (Pack of 1)',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Master Your Data with Power Query in Excel and Power BI: Leveraging Power Query to Get & Transform Your Task Flow  ',
#   'price': '19.',
#   'rating': 'by ',
#   'oprice': '$19.39'},
#  {'brand': None,
#   'title': 'Excel Power Pivot & Power Query For Dummies  ',
#   'price': '25.',
#   'rating': 'by ',
#   'oprice': '$25.49'},
#  {'brand': None,
#   'title': 'Starry Messenger: Cosmic Perspectives on Civilization  ',
#   'price': '0.',
#   'rating': 'by ',
#   'oprice': '$0.00'},
#  {'brand': None,
#   'title': 'Optima Batteries 8004-003 34/78 RedTop Starting Battery  ',
#   'price': None,
#   'rating': '4.5',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Today is NOT the Day We Die  ',
#   'price': '6.',
#   'rating': 'by ',
#   'oprice': '$6.99'},
#  {'brand': None,
#   'title': 'Quercetin | Sugar Free | Liquid Quercetin 500mg Immune Support for Adults & Kids | Inflammation Support Supplement | Immune Defense | Cellular Health | Vegan | Non-GMO | Gluten Free | 4 Fl Oz  ',
#   'price': '20.',
#   'rating': '4 Fl Oz (Pack of 1)',
#   'oprice': '$20.25'},
#  {'brand': None,
#   'title': 'The Ultimate Guide to Power Query: A Step-By-Step Guide on Using Power Query Effectively for Data Transformation  ',
#   'price': '12.',
#   'rating': 'by ',
#   'oprice': '$12.00'},
#  {'brand': None,
#   'title': 'Solgar Quercetin Complex with Ester-C Plus, 100 Vegetable Capsules - Supports Immune Health, Antioxidant - Gentle on the Stomach Vitamin C - Non-GMO, Vegan, Gluten / Dairy Free - 50 Servings  ',
#   'price': None,
#   'rating': '100 Count (Pack of 1)',
#   'oprice': None},
#  {'brand': None,
#   'title': 'SQL Queries 2012 Joes 2 Pros 5 Volume (DVD) Certification Training Tutorial for Microsoft Exam 70-461  ',
#   'price': None,
#   'rating': None,
#   'oprice': None},
#  {'brand': None,
#   'title': 'Pee Wee Serial Killer or Homicidal Maniac: A Novelized True Crime Story, Volume I  ',
#   'price': '2.',
#   'rating': 'by ',
#   'oprice': '$2.99'},
#  {'brand': None,
#   'title': 'SQL Server 2022 Query Performance Tuning: Troubleshoot and Optimize Query Performance  ',
#   'price': '54.',
#   'rating': 'by ',
#   'oprice': '$54.64'},
#  {'brand': None,
#   'title': 'Hands-on Site Reliability Engineering: Build Capability to Design, Deploy, Monitor, and Sustain Enterprise Software Systems at Scale (English Edition)  ',
#   'price': '29.',
#   'rating': 'by ',
#   'oprice': '$29.95'},
#  {'brand': None,
#   'title': 'My Inner Sanctuary Journal  ',
#   'price': '9.',
#   'rating': 'by ',
#   'oprice': '$9.99'},
#  {'brand': None,
#   'title': 'Cloud Computing Using Salesforce: Build and Customize Applications for your business using the Salesforce Platform (English Edition)  ',
#   'price': '24.',
#   'rating': 'by ',
#   'oprice': '$24.95'},
#  {'brand': None,
#   'title': "Modern Oracle Enterprise Architecture: Discover Oracle's Hidden Gems for Next Generation Database and Application Migrations (English Edition)  ",
#   'price': '6.',
#   'rating': 'by ',
#   'oprice': '$6.70'},
#  {'brand': None,
#   'title': 'Mastering Azure Kubernetes Service (AKS): Rapidly Build and Scale Your Containerized Applications with Microsoft Azure Kubernetes Service (English Edition)  ',
#   'price': '29.',
#   'rating': 'by ',
#   'oprice': '$29.95'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': ' or ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': 'Price and other details may vary based on product size and color.',
#   'oprice': None},
#  {'brand': None,
#   'title': "Cosmic Queries: StarTalk's Guide to Who We Are, How We Got Here, and Where We're Going  ",
#   'price': '22.',
#   'rating': 'by ',
#   'oprice': '$22.49'},
#  {'brand': None,
#   'title': 'Quaker Queries for All Seasons  ',
#   'price': '9.',
#   'rating': 'by ',
#   'oprice': '$9.99'},
#  {'brand': None,
#   'title': 'SQL Queries for Mere Mortals: A Hands-On Guide to Data Manipulation in SQL  ',
#   'price': '40.',
#   'rating': '4.5',
#   'oprice': '$40.99'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': 'Old Country  ',
#   'price': '0.',
#   'rating': 'by ',
#   'oprice': '$0.00'},
#  {'brand': None,
#   'title': 'EXCEL 2022 POWER PIVOT & POWER QUERY FOR BEGINNERS: COMPLETE STEP-BY-STEP PRACTICAL GUIDE WITH EXAMPLES FOR MASTERING EXCEL POWER PIVOT AND POWER ... IMPORTATION, TRANSFORMATION, AND MODELLING  ',
#   'price': '12.',
#   'rating': '3.5',
#   'oprice': '$12.99'},
#  {'brand': None,
#   'title': 'SQL Cookbook: Query Solutions and Techniques for All SQL Users  ',
#   'price': '24.',
#   'rating': 'by ',
#   'oprice': '$24.96'},
#  {'brand': None,
#   'title': 'Query: Everything You Need To Get Started, Get Noticed, and Get Signed  ',
#   'price': '3.',
#   'rating': 'by ',
#   'oprice': '$3.99'},
#  {'brand': None,
#   'title': 'The Failsafe Query: The high risk search for a spy legacy (Failsafe Thrillers)  ',
#   'price': '9.',
#   'rating': '4.0',
#   'oprice': '$9.08'},
#  {'brand': None,
#   'title': 'Quarrys, Queries  ',
#   'price': None,
#   'rating': 'by ',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Easy Sim USSD, Query, Recharge  ',
#   'price': None,
#   'rating': 'Nov 13, 2016',
#   'oprice': None},
#  {'brand': None,
#   'title': 'The Big Book Of SQL Queries: 250+ SQL Practice Queries (SQL Series)  ',
#   'price': '24.',
#   'rating': '4.6',
#   'oprice': '$24.95'},
#  {'brand': None,
#   'title': 'Query Craft: The Writer-in-the-Know Guide to Getting Your Manuscript Requested  ',
#   'price': '11.',
#   'rating': 'by ',
#   'oprice': '$11.99'},
#  {'brand': None,
#   'title': 'Jackery Portable Power Station Explorer 240, 240Wh Backup Lithium Battery, 110V/200W Pure Sine Wave AC Outlet, Solar Generator (Solar Panel Not Included) for Outdoors Camping Travel Hunting Emergency  ',
#   'price': None,
#   'rating': '4.7',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Query  ',
#   'price': '0.',
#   'rating': '2020',
#   'oprice': '$0.99'},
#  {'brand': None,
#   'title': 'Milwaukee 48-11-1880 M18 REDLITHIUM HIGH OUTPUT 18v 8.0 Ah Lithium-Ion Battery Pack  ',
#   'price': '118.',
#   'rating': '4.8',
#   'oprice': '$118.00'},
#  {'brand': None,
#   'title': 'Betsey Johnson Woven Mixed Multi-Colored Bead Flower Heart Illusion Necklace  ',
#   'price': '48.',
#   'rating': '4.4',
#   'oprice': '$48.00'},
#  {'brand': None,
#   'title': 'DEWALT 20V MAX Battery, 2 Ah and 4 Ah, 4-Pack, Fuel Gauge LED Charge Indicators(DCB324-4)  ',
#   'price': '172.',
#   'rating': '4.8',
#   'oprice': '$172.99'},
#  {'brand': None,
#   'title': 'Thorne Quercetin Phytosome - Exclusive Phytosome Complex for Immune Health, Respiratory Support, and Seasonal Allergy Relief - 60 Capsules  ',
#   'price': '37.',
#   'rating': '60 Count (Pack of 1)',
#   'oprice': '$37.98'},
#  {'brand': None,
#   'title': 'Live Nude Girls Unite!  ',
#   'price': '3.',
#   'rating': '2000',
#   'oprice': '$3.99'},
#  {'brand': None,
#   'title': 'Energizer 2032 Batteries, Lithium CR2032 Watch Battery, 6 Count  ',
#   'price': None,
#   'rating': '6 Count (Pack of 1)',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Milwaukee M18 48-11-1850 5.0 AH Batteries 5.0 18V 48-11-1852 (2 pack)  ',
#   'price': None,
#   'rating': '4.7',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Adobe Acrobat Professional DC | Create, edit and sign PDF documents | 1-month Subscription with auto-renewal, PC/Mac  ',
#   'price': '24.',
#   'rating': '3.9',
#   'oprice': '$24.99'},
#  {'brand': None,
#   'title': 'DEWALT 20V MAX XR Battery, Lithium Ion, 5.0Ah (DCB205)  ',
#   'price': '70.',
#   'rating': '4.7',
#   'oprice': '$70.95'},
#  {'brand': None,
#   'title': 'NOW Supplements, Quercetin with Bromelain, Balanced Immune System*, 120 Veg Capsules  ',
#   'price': '15.',
#   'rating': '4.7',
#   'oprice': '$15.11'},
#  {'brand': None,
#   'title': 'Amazing Formulas Quercetin 500mg 120 Veggie Capsules Supplement - Non-GMO - Gluten Free - Supports Overall Health & Well Being  ',
#   'price': '19.',
#   'rating': '120 Count (Pack of 1)',
#   'oprice': '$19.99'},
#  {'brand': None,
#   'title': 'Jarrow Formulas Quercetin 500 mg - Supports Antioxidant Status, Cardiovascular Health & Immune Health - Dietary Supplement - 100 Servings (Veggie Caps) (Packaging May Vary)  ',
#   'price': '22.',
#   'rating': '100 Count (Pack of 1)',
#   'oprice': '$22.77'},
#  {'brand': None,
#   'title': 'Creating a Query with Microsoft Access 2007  ',
#   'price': None,
#   'rating': '2017',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Energizer 2032 Batteries, Lithium CR2032 Watch Battery, 4 Count  ',
#   'price': None,
#   'rating': '4 Count (Pack of 1)',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Milwaukee 48-11-1850 M18 Redlithium 5.0Ah Bat Pack  ',
#   'price': '61.',
#   'rating': '4.8',
#   'oprice': '$61.99'},
#  {'brand': None,
#   'title': 'NatureBell Quercetin 1000mg Per Serving | 240 Capsules, Ultra Strength Quercetin Supplement | Bioflavonoids for Healthy Immune Support, Third Party Tested, Non-GMO & No Gluten  ',
#   'price': '26.',
#   'rating': '240 Count (Pack of 1)',
#   'oprice': '$26.95'},
#  {'brand': None,
#   'title': 'Zinc Quercetin 120 Vegetarian Capsules  ',
#   'price': '24.',
#   'rating': '120 Count (Pack of 1)',
#   'oprice': '$24.95'},
#  {'brand': None,
#   'title': 'SOLARAY Quercetin 500 mg, Supports Sinus, Respiratory, Immune Function & Normal, Healthy Uric Acid Levels, 90 VegCaps  ',
#   'price': '23.',
#   'rating': '90 Count (Pack of 1)',
#   'oprice': '$23.39'},
#  {'brand': None,
#   'title': 'SVP‑916 100‑130VAC Adjustable Over and Under Voltage Protector, Delay Reset Protector, with Reset Mode Selection, Fault Query and Factory Reset Function  ',
#   'price': '17.',
#   'rating': '4.5',
#   'oprice': '$17.20'},
#  {'brand': None,
#   'title': 'SQL Server 2017 Query Performance Tuning: Troubleshoot and Optimize Query Performance  ',
#   'price': '38.',
#   'rating': 'by ',
#   'oprice': '$38.03'},
#  {'brand': None,
#   'title': '8.4 - 2. Working with Media Queries  ',
#   'price': None,
#   'rating': '2017',
#   'oprice': None},
#  {'brand': None,
#   'title': "Doctor's Best Quercetin Bromelain, Immunity Support, Heart, Joint & Healthy Respiratory System, Non-GMO, Vegan, Gluten Free, Soy Free,180 VC  ",
#   'price': '21.',
#   'rating': '180 Count (Pack of 1)',
#   'oprice': '$21.68'},
#  {'brand': None,
#   'title': 'Duracell CR2032 3V Lithium Battery, Child Safety Features, 6 Count Pack, Lithium Coin Battery for Key Fob, Car Remote, Glucose Monitor, CR Lithium 3 Volt Cell  ',
#   'price': None,
#   'rating': '6 Count (Pack of 1)',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Master Your Data with Power Query in Excel and Power BI: Leveraging Power Query to Get & Transform Your Task Flow  ',
#   'price': '19.',
#   'rating': 'by ',
#   'oprice': '$19.39'},
#  {'brand': None,
#   'title': 'Excel Power Pivot & Power Query For Dummies  ',
#   'price': '25.',
#   'rating': 'by ',
#   'oprice': '$25.49'},
#  {'brand': None,
#   'title': 'The Ultimate Guide to Power Query: A Step-By-Step Guide on Using Power Query Effectively for Data Transformation  ',
#   'price': '12.',
#   'rating': 'by ',
#   'oprice': '$12.00'},
#  {'brand': None,
#   'title': 'Optima Batteries 8004-003 34/78 RedTop Starting Battery  ',
#   'price': None,
#   'rating': '4.5',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Starry Messenger: Cosmic Perspectives on Civilization  ',
#   'price': '0.',
#   'rating': 'by ',
#   'oprice': '$0.00'},
#  {'brand': None,
#   'title': 'Today is NOT the Day We Die  ',
#   'price': '6.',
#   'rating': 'by ',
#   'oprice': '$6.99'},
#  {'brand': None,
#   'title': 'Quercetin | Sugar Free | Liquid Quercetin 500mg Immune Support for Adults & Kids | Inflammation Support Supplement | Immune Defense | Cellular Health | Vegan | Non-GMO | Gluten Free | 4 Fl Oz  ',
#   'price': '20.',
#   'rating': '4 Fl Oz (Pack of 1)',
#   'oprice': '$20.25'},
#  {'brand': None,
#   'title': 'SQL Queries 2012 Joes 2 Pros 5 Volume (DVD) Certification Training Tutorial for Microsoft Exam 70-461  ',
#   'price': None,
#   'rating': 'No reviews',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Solgar Quercetin Complex with Ester-C Plus, 100 Vegetable Capsules - Supports Immune Health, Antioxidant - Gentle on the Stomach Vitamin C - Non-GMO, Vegan, Gluten / Dairy Free - 50 Servings  ',
#   'price': None,
#   'rating': '100 Count (Pack of 1)',
#   'oprice': None},
#  {'brand': None,
#   'title': 'SQL Server 2022 Query Performance Tuning: Troubleshoot and Optimize Query Performance  ',
#   'price': '54.',
#   'rating': 'by ',
#   'oprice': '$54.64'},
#  {'brand': None,
#   'title': 'Pee Wee Serial Killer or Homicidal Maniac: A Novelized True Crime Story, Volume I  ',
#   'price': '2.',
#   'rating': 'by ',
#   'oprice': '$2.99'},
#  {'brand': None,
#   'title': 'Learn SQL in a weekend: The definitive guide for creating and querying databases  ',
#   'price': '8.',
#   'rating': '4.4',
#   'oprice': '$8.99'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': ' or ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': 'Price and other details may vary based on product size and color.',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Quaker Queries for All Seasons  ',
#   'price': '9.',
#   'rating': 'by ',
#   'oprice': '$9.99'},
#  {'brand': None,
#   'title': "Cosmic Queries: StarTalk's Guide to Who We Are, How We Got Here, and Where We're Going  ",
#   'price': '22.',
#   'rating': 'by ',
#   'oprice': '$22.49'},
#  {'brand': None,
#   'title': 'SQL Queries for Mere Mortals: A Hands-On Guide to Data Manipulation in SQL  ',
#   'price': '40.',
#   'rating': '4.5',
#   'oprice': '$40.99'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': 'Old Country  ',
#   'price': '0.',
#   'rating': 'by ',
#   'oprice': '$0.00'},
#  {'brand': None,
#   'title': 'EXCEL 2022 POWER PIVOT & POWER QUERY FOR BEGINNERS: COMPLETE STEP-BY-STEP PRACTICAL GUIDE WITH EXAMPLES FOR MASTERING EXCEL POWER PIVOT AND POWER ... IMPORTATION, TRANSFORMATION, AND MODELLING  ',
#   'price': '12.',
#   'rating': '3.5',
#   'oprice': '$12.99'},
#  {'brand': None,
#   'title': 'SQL Cookbook: Query Solutions and Techniques for All SQL Users  ',
#   'price': '24.',
#   'rating': 'by ',
#   'oprice': '$24.96'},
#  {'brand': None,
#   'title': 'The Failsafe Query: The high risk search for a spy legacy (Failsafe Thrillers)  ',
#   'price': '9.',
#   'rating': '4.0',
#   'oprice': '$9.08'},
#  {'brand': None,
#   'title': 'Query: Everything You Need To Get Started, Get Noticed, and Get Signed  ',
#   'price': '3.',
#   'rating': 'by ',
#   'oprice': '$3.99'},
#  {'brand': None,
#   'title': 'Quarrys, Queries  ',
#   'price': None,
#   'rating': 'by ',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Easy Sim USSD, Query, Recharge  ',
#   'price': None,
#   'rating': 'Nov 13, 2016',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': 'The Big Book Of SQL Queries: 250+ SQL Practice Queries (SQL Series)  ',
#   'price': '24.',
#   'rating': '4.6',
#   'oprice': '$24.95'},
#  {'brand': None,
#   'title': 'SQL Server 2017 Query Performance Tuning: Troubleshoot and Optimize Query Performance  ',
#   'price': '38.',
#   'rating': 'by ',
#   'oprice': '$38.03'},
#  {'brand': None,
#   'title': 'Milwaukee 48-11-1880 M18 REDLITHIUM HIGH OUTPUT 18v 8.0 Ah Lithium-Ion Battery Pack  ',
#   'price': '118.',
#   'rating': '4.8',
#   'oprice': '$118.00'},
#  {'brand': None,
#   'title': 'Query  ',
#   'price': '0.',
#   'rating': '2020',
#   'oprice': '$0.99'},
#  {'brand': None,
#   'title': 'Jackery Portable Power Station Explorer 240, 240Wh Backup Lithium Battery, 110V/200W Pure Sine Wave AC Outlet, Solar Generator (Solar Panel Not Included) for Outdoors Camping Travel Hunting Emergency  ',
#   'price': None,
#   'rating': '4.7',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Betsey Johnson Woven Mixed Multi-Colored Bead Flower Heart Illusion Necklace  ',
#   'price': '48.',
#   'rating': '4.4',
#   'oprice': '$48.00'},
#  {'brand': None,
#   'title': 'DEWALT 20V MAX Battery, 2 Ah and 4 Ah, 4-Pack, Fuel Gauge LED Charge Indicators(DCB324-4)  ',
#   'price': '172.',
#   'rating': '4.8',
#   'oprice': '$172.99'},
#  {'brand': None,
#   'title': 'Thorne Quercetin Phytosome - Exclusive Phytosome Complex for Immune Health, Respiratory Support, and Seasonal Allergy Relief - 60 Capsules  ',
#   'price': '37.',
#   'rating': '60 Count (Pack of 1)',
#   'oprice': '$37.98'},
#  {'brand': None,
#   'title': 'Live Nude Girls Unite!  ',
#   'price': '3.',
#   'rating': '2000',
#   'oprice': '$3.99'},
#  {'brand': None,
#   'title': 'DEWALT 20V MAX XR Battery, Lithium Ion, 5.0Ah (DCB205)  ',
#   'price': '70.',
#   'rating': '4.7',
#   'oprice': '$70.95'},
#  {'brand': None,
#   'title': 'Energizer 2032 Batteries, Lithium CR2032 Watch Battery, 6 Count  ',
#   'price': None,
#   'rating': '6 Count (Pack of 1)',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Adobe Acrobat Professional DC | Create, edit and sign PDF documents | 1-month Subscription with auto-renewal, PC/Mac  ',
#   'price': '24.',
#   'rating': '3.9',
#   'oprice': '$24.99'},
#  {'brand': None,
#   'title': 'Milwaukee M18 48-11-1850 5.0 AH Batteries 5.0 18V 48-11-1852 (2 pack)  ',
#   'price': None,
#   'rating': '4.7',
#   'oprice': None},
#  {'brand': None,
#   'title': 'NOW Supplements, Quercetin with Bromelain, Balanced Immune System*, 120 Veg Capsules  ',
#   'price': '15.',
#   'rating': '4.7',
#   'oprice': '$15.11'},
#  {'brand': None,
#   'title': 'Amazing Formulas Quercetin 500mg 120 Veggie Capsules Supplement - Non-GMO - Gluten Free - Supports Overall Health & Well Being  ',
#   'price': '19.',
#   'rating': '120 Count (Pack of 1)',
#   'oprice': '$19.99'},
#  {'brand': None,
#   'title': 'Jarrow Formulas Quercetin 500 mg - Supports Antioxidant Status, Cardiovascular Health & Immune Health - Dietary Supplement - 100 Servings (Veggie Caps) (Packaging May Vary)  ',
#   'price': '22.',
#   'rating': '100 Count (Pack of 1)',
#   'oprice': '$22.77'},
#  {'brand': None,
#   'title': 'NatureBell Quercetin 1000mg Per Serving | 240 Capsules, Ultra Strength Quercetin Supplement | Bioflavonoids for Healthy Immune Support, Third Party Tested, Non-GMO & No Gluten  ',
#   'price': '26.',
#   'rating': '240 Count (Pack of 1)',
#   'oprice': '$26.95'},
#  {'brand': None,
#   'title': 'Zinc Quercetin 120 Vegetarian Capsules  ',
#   'price': '24.',
#   'rating': '120 Count (Pack of 1)',
#   'oprice': '$24.95'},
#  {'brand': None,
#   'title': 'Creating a Query with Microsoft Access 2007  ',
#   'price': None,
#   'rating': '2017',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Energizer 2032 Batteries, Lithium CR2032 Watch Battery, 4 Count  ',
#   'price': None,
#   'rating': '4 Count (Pack of 1)',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Milwaukee 48-11-1850 M18 Redlithium 5.0Ah Bat Pack  ',
#   'price': '61.',
#   'rating': '4.8',
#   'oprice': '$61.99'},
#  {'brand': None,
#   'title': 'SOLARAY Quercetin 500 mg, Supports Sinus, Respiratory, Immune Function & Normal, Healthy Uric Acid Levels, 90 VegCaps  ',
#   'price': '23.',
#   'rating': '90 Count (Pack of 1)',
#   'oprice': '$23.39'},
#  {'brand': None,
#   'title': 'SVP‑916 100‑130VAC Adjustable Over and Under Voltage Protector, Delay Reset Protector, with Reset Mode Selection, Fault Query and Factory Reset Function  ',
#   'price': '17.',
#   'rating': '4.5',
#   'oprice': '$17.20'},
#  {'brand': None,
#   'title': 'Query Craft: The Writer-in-the-Know Guide to Getting Your Manuscript Requested  ',
#   'price': '11.',
#   'rating': 'by ',
#   'oprice': '$11.99'},
#  {'brand': None,
#   'title': "Doctor's Best Quercetin Bromelain, Immunity Support, Heart, Joint & Healthy Respiratory System, Non-GMO, Vegan, Gluten Free, Soy Free,180 VC  ",
#   'price': '21.',
#   'rating': '180 Count (Pack of 1)',
#   'oprice': '$21.68'},
#  {'brand': None,
#   'title': '8.4 - 2. Working with Media Queries  ',
#   'price': None,
#   'rating': '2017',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Duracell CR2032 3V Lithium Battery, Child Safety Features, 6 Count Pack, Lithium Coin Battery for Key Fob, Car Remote, Glucose Monitor, CR Lithium 3 Volt Cell  ',
#   'price': None,
#   'rating': '6 Count (Pack of 1)',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Master Your Data with Power Query in Excel and Power BI: Leveraging Power Query to Get & Transform Your Task Flow  ',
#   'price': '19.',
#   'rating': 'by ',
#   'oprice': '$19.39'},
#  {'brand': None,
#   'title': 'Excel Power Pivot & Power Query For Dummies  ',
#   'price': '25.',
#   'rating': 'by ',
#   'oprice': '$25.49'},
#  {'brand': None,
#   'title': 'Optima Batteries 8004-003 34/78 RedTop Starting Battery  ',
#   'price': None,
#   'rating': '4.5',
#   'oprice': None},
#  {'brand': None,
#   'title': 'The Ultimate Guide to Power Query: A Step-By-Step Guide on Using Power Query Effectively for Data Transformation  ',
#   'price': '12.',
#   'rating': 'by ',
#   'oprice': '$12.00'},
#  {'brand': None,
#   'title': 'Solgar Quercetin Complex with Ester-C Plus, 100 Vegetable Capsules - Supports Immune Health, Antioxidant - Gentle on the Stomach Vitamin C - Non-GMO, Vegan, Gluten / Dairy Free - 50 Servings  ',
#   'price': None,
#   'rating': '100 Count (Pack of 1)',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Starry Messenger: Cosmic Perspectives on Civilization  ',
#   'price': '0.',
#   'rating': 'by ',
#   'oprice': '$0.00'},
#  {'brand': None,
#   'title': 'Quercetin | Sugar Free | Liquid Quercetin 500mg Immune Support for Adults & Kids | Inflammation Support Supplement | Immune Defense | Cellular Health | Vegan | Non-GMO | Gluten Free | 4 Fl Oz  ',
#   'price': '20.',
#   'rating': '4 Fl Oz (Pack of 1)',
#   'oprice': '$20.25'},
#  {'brand': None,
#   'title': 'SQL Server 2022 Query Performance Tuning: Troubleshoot and Optimize Query Performance  ',
#   'price': '54.',
#   'rating': 'by ',
#   'oprice': '$54.64'},
#  {'brand': None,
#   'title': 'SQL Queries 2012 Joes 2 Pros 5 Volume (DVD) Certification Training Tutorial for Microsoft Exam 70-461  ',
#   'price': None,
#   'rating': 'No reviews',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Collect, Combine, and Transform Data Using Power Query in Excel and Power BI (Business Skills)  ',
#   'price': '36.',
#   'rating': '4.6',
#   'oprice': '$36.53'},
#  {'brand': None,
#   'title': 'Amazon Basics 4 Pack CR2032 3 Volt Lithium Coin Cell Battery  ',
#   'price': None,
#   'rating': '4.7',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': ' or ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': 'Price and other details may vary based on product size and color.',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Quaker Queries for All Seasons  ',
#   'price': '9.',
#   'rating': 'by ',
#   'oprice': '$9.99'},
#  {'brand': None,
#   'title': "Cosmic Queries: StarTalk's Guide to Who We Are, How We Got Here, and Where We're Going  ",
#   'price': '22.',
#   'rating': 'by ',
#   'oprice': '$22.49'},
#  {'brand': None,
#   'title': 'SQL Queries for Mere Mortals: A Hands-On Guide to Data Manipulation in SQL  ',
#   'price': '40.',
#   'rating': '4.5',
#   'oprice': '$40.99'},
#  {'brand': None,
#   'title': 'Old Country  ',
#   'price': '0.',
#   'rating': 'by ',
#   'oprice': '$0.00'},
#  {'brand': None,
#   'title': 'EXCEL 2022 POWER PIVOT & POWER QUERY FOR BEGINNERS: COMPLETE STEP-BY-STEP PRACTICAL GUIDE WITH EXAMPLES FOR MASTERING EXCEL POWER PIVOT AND POWER ... IMPORTATION, TRANSFORMATION, AND MODELLING  ',
#   'price': '12.',
#   'rating': '3.5',
#   'oprice': '$12.99'},
#  {'brand': None,
#   'title': 'SQL Cookbook: Query Solutions and Techniques for All SQL Users  ',
#   'price': '24.',
#   'rating': 'by ',
#   'oprice': '$24.96'},
#  {'brand': None,
#   'title': 'The Failsafe Query: The high risk search for a spy legacy (Failsafe Thrillers)  ',
#   'price': '9.',
#   'rating': '4.0',
#   'oprice': '$9.08'},
#  {'brand': None,
#   'title': 'Query: Everything You Need To Get Started, Get Noticed, and Get Signed  ',
#   'price': '3.',
#   'rating': 'by ',
#   'oprice': '$3.99'},
#  {'brand': None,
#   'title': 'Quarrys, Queries  ',
#   'price': None,
#   'rating': 'by ',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Easy Sim USSD, Query, Recharge  ',
#   'price': None,
#   'rating': 'Nov 13, 2016',
#   'oprice': None},
#  {'brand': None,
#   'title': 'The Big Book Of SQL Queries: 250+ SQL Practice Queries (SQL Series)  ',
#   'price': '24.',
#   'rating': '4.6',
#   'oprice': '$24.95'},
#  {'brand': None,
#   'title': 'SQL Server 2017 Query Performance Tuning: Troubleshoot and Optimize Query Performance  ',
#   'price': '38.',
#   'rating': 'by ',
#   'oprice': '$38.03'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': 'Jackery Portable Power Station Explorer 240, 240Wh Backup Lithium Battery, 110V/200W Pure Sine Wave AC Outlet, Solar Generator (Solar Panel Not Included) for Outdoors Camping Travel Hunting Emergency  ',
#   'price': None,
#   'rating': '4.7',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Query  ',
#   'price': '0.',
#   'rating': '2020',
#   'oprice': '$0.99'},
#  {'brand': None,
#   'title': 'Milwaukee 48-11-1880 M18 REDLITHIUM HIGH OUTPUT 18v 8.0 Ah Lithium-Ion Battery Pack  ',
#   'price': '118.',
#   'rating': '4.8',
#   'oprice': '$118.00'},
#  {'brand': None,
#   'title': 'Betsey Johnson Woven Mixed Multi-Colored Bead Flower Heart Illusion Necklace  ',
#   'price': '48.',
#   'rating': '4.4',
#   'oprice': '$48.00'},
#  {'brand': None,
#   'title': 'DEWALT 20V MAX Battery, 2 Ah and 4 Ah, 4-Pack, Fuel Gauge LED Charge Indicators(DCB324-4)  ',
#   'price': '172.',
#   'rating': '4.8',
#   'oprice': '$172.99'},
#  {'brand': None,
#   'title': 'Thorne Quercetin Phytosome - Exclusive Phytosome Complex for Immune Health, Respiratory Support, and Seasonal Allergy Relief - 60 Capsules  ',
#   'price': '37.',
#   'rating': '60 Count (Pack of 1)',
#   'oprice': '$37.98'},
#  {'brand': None,
#   'title': 'Live Nude Girls Unite!  ',
#   'price': '3.',
#   'rating': '2000',
#   'oprice': '$3.99'},
#  {'brand': None,
#   'title': 'Milwaukee M18 48-11-1850 5.0 AH Batteries 5.0 18V 48-11-1852 (2 pack)  ',
#   'price': None,
#   'rating': '4.7',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Energizer 2032 Batteries, Lithium CR2032 Watch Battery, 6 Count  ',
#   'price': None,
#   'rating': '6 Count (Pack of 1)',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Adobe Acrobat Professional DC | Create, edit and sign PDF documents | 1-month Subscription with auto-renewal, PC/Mac  ',
#   'price': '24.',
#   'rating': '3.9',
#   'oprice': '$24.99'},
#  {'brand': None,
#   'title': 'DEWALT 20V MAX XR Battery, Lithium Ion, 5.0Ah (DCB205)  ',
#   'price': '70.',
#   'rating': '4.7',
#   'oprice': '$70.95'},
#  {'brand': None,
#   'title': 'NOW Supplements, Quercetin with Bromelain, Balanced Immune System*, 120 Veg Capsules  ',
#   'price': '15.',
#   'rating': '4.7',
#   'oprice': '$15.11'},
#  {'brand': None,
#   'title': 'Amazing Formulas Quercetin 500mg 120 Veggie Capsules Supplement - Non-GMO - Gluten Free - Supports Overall Health & Well Being  ',
#   'price': '19.',
#   'rating': '120 Count (Pack of 1)',
#   'oprice': '$19.99'},
#  {'brand': None,
#   'title': 'Jarrow Formulas Quercetin 500 mg - Supports Antioxidant Status, Cardiovascular Health & Immune Health - Dietary Supplement - 100 Servings (Veggie Caps) (Packaging May Vary)  ',
#   'price': '22.',
#   'rating': '100 Count (Pack of 1)',
#   'oprice': '$22.77'},
#  {'brand': None,
#   'title': 'Creating a Query with Microsoft Access 2007  ',
#   'price': None,
#   'rating': '2017',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Milwaukee 48-11-1850 M18 Redlithium 5.0Ah Bat Pack  ',
#   'price': '61.',
#   'rating': '4.8',
#   'oprice': '$61.99'},
#  {'brand': None,
#   'title': 'Energizer 2032 Batteries, Lithium CR2032 Watch Battery, 4 Count  ',
#   'price': None,
#   'rating': '4 Count (Pack of 1)',
#   'oprice': None},
#  {'brand': None,
# ...
#   'price': '37.',
#   'rating': '60 Count (Pack of 1)',
#   'oprice': '$37.98'},
#  {'brand': None,
#   'title': 'Live Nude Girls Unite!  ',
#   'price': '3.',
#   'rating': '2000',
#   'oprice': '$3.99'},
#  {'brand': None,
#   'title': 'Energizer 2032 Batteries, Lithium CR2032 Watch Battery, 6 Count  ',
#   'price': None,
#   'rating': '6 Count (Pack of 1)',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Milwaukee M18 48-11-1850 5.0 AH Batteries 5.0 18V 48-11-1852 (2 pack)  ',
#   'price': None,
#   'rating': '4.7',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Adobe Acrobat Professional DC | Create, edit and sign PDF documents | 1-month Subscription with auto-renewal, PC/Mac  ',
#   'price': '24.',
#   'rating': '3.9',
#   'oprice': '$24.99'},
#  {'brand': None,
#   'title': 'DEWALT 20V MAX XR Battery, Lithium Ion, 5.0Ah (DCB205)  ',
#   'price': '70.',
#   'rating': '4.7',
#   'oprice': '$70.95'},
#  {'brand': None,
#   'title': 'NOW Supplements, Quercetin with Bromelain, Balanced Immune System*, 120 Veg Capsules  ',
#   'price': '15.',
#   'rating': '4.7',
#   'oprice': '$15.11'},
#  {'brand': None,
#   'title': 'Amazing Formulas Quercetin 500mg 120 Veggie Capsules Supplement - Non-GMO - Gluten Free - Supports Overall Health & Well Being  ',
#   'price': '19.',
#   'rating': '120 Count (Pack of 1)',
#   'oprice': '$19.99'},
#  {'brand': None,
#   'title': 'Jarrow Formulas Quercetin 500 mg - Supports Antioxidant Status, Cardiovascular Health & Immune Health - Dietary Supplement - 100 Servings (Veggie Caps) (Packaging May Vary)  ',
#   'price': '22.',
#   'rating': '100 Count (Pack of 1)',
#   'oprice': '$22.77'},
#  {'brand': None,
#   'title': 'Creating a Query with Microsoft Access 2007  ',
#   'price': None,
#   'rating': '2017',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Energizer 2032 Batteries, Lithium CR2032 Watch Battery, 4 Count  ',
#   'price': None,
#   'rating': '4 Count (Pack of 1)',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Milwaukee 48-11-1850 M18 Redlithium 5.0Ah Bat Pack  ',
#   'price': '61.',
#   'rating': '4.8',
#   'oprice': '$61.99'},
#  {'brand': None,
#   'title': 'NatureBell Quercetin 1000mg Per Serving | 240 Capsules, Ultra Strength Quercetin Supplement | Bioflavonoids for Healthy Immune Support, Third Party Tested, Non-GMO & No Gluten  ',
#   'price': '26.',
#   'rating': '240 Count (Pack of 1)',
#   'oprice': '$26.95'},
#  {'brand': None,
#   'title': 'Zinc Quercetin 120 Vegetarian Capsules  ',
#   'price': '24.',
#   'rating': '120 Count (Pack of 1)',
#   'oprice': '$24.95'},
#  {'brand': None,
#   'title': 'SOLARAY Quercetin 500 mg, Supports Sinus, Respiratory, Immune Function & Normal, Healthy Uric Acid Levels, 90 VegCaps  ',
#   'price': '23.',
#   'rating': '90 Count (Pack of 1)',
#   'oprice': '$23.39'},
#  {'brand': None,
#   'title': 'SVP‑916 100‑130VAC Adjustable Over and Under Voltage Protector, Delay Reset Protector, with Reset Mode Selection, Fault Query and Factory Reset Function  ',
#   'price': '17.',
#   'rating': '4.5',
#   'oprice': '$17.20'},
#  {'brand': None,
#   'title': 'SQL Server 2017 Query Performance Tuning: Troubleshoot and Optimize Query Performance  ',
#   'price': '38.',
#   'rating': 'by ',
#   'oprice': '$38.03'},
#  {'brand': None,
#   'title': '8.4 - 2. Working with Media Queries  ',
#   'price': None,
#   'rating': '2017',
#   'oprice': None},
#  {'brand': None,
#   'title': "Doctor's Best Quercetin Bromelain, Immunity Support, Heart, Joint & Healthy Respiratory System, Non-GMO, Vegan, Gluten Free, Soy Free,180 VC  ",
#   'price': '21.',
#   'rating': '180 Count (Pack of 1)',
#   'oprice': '$21.68'},
#  {'brand': None,
#   'title': 'My Inner Sanctuary Journal  ',
#   'price': '9.',
#   'rating': 'by ',
#   'oprice': '$9.99'},
#  {'brand': None,
#   'title': 'Duracell CR2032 3V Lithium Battery, Child Safety Features, 6 Count Pack, Lithium Coin Battery for Key Fob, Car Remote, Glucose Monitor, CR Lithium 3 Volt Cell  ',
#   'price': None,
#   'rating': '6 Count (Pack of 1)',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Master Your Data with Power Query in Excel and Power BI: Leveraging Power Query to Get & Transform Your Task Flow  ',
#   'price': '19.',
#   'rating': 'by ',
#   'oprice': '$19.39'},
#  {'brand': None,
#   'title': 'Excel Power Pivot & Power Query For Dummies  ',
#   'price': '25.',
#   'rating': 'by ',
#   'oprice': '$25.49'},
#  {'brand': None,
#   'title': 'The Ultimate Guide to Power Query: A Step-By-Step Guide on Using Power Query Effectively for Data Transformation  ',
#   'price': '12.',
#   'rating': 'by ',
#   'oprice': '$12.00'},
#  {'brand': None,
#   'title': 'Optima Batteries 8004-003 34/78 RedTop Starting Battery  ',
#   'price': None,
#   'rating': '4.5',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Starry Messenger: Cosmic Perspectives on Civilization  ',
#   'price': '0.',
#   'rating': 'by ',
#   'oprice': '$0.00'},
#  {'brand': None,
#   'title': 'Today is NOT the Day We Die  ',
#   'price': '6.',
#   'rating': 'by ',
#   'oprice': '$6.99'},
#  {'brand': None,
#   'title': 'Quercetin | Sugar Free | Liquid Quercetin 500mg Immune Support for Adults & Kids | Inflammation Support Supplement | Immune Defense | Cellular Health | Vegan | Non-GMO | Gluten Free | 4 Fl Oz  ',
#   'price': '20.',
#   'rating': '4 Fl Oz (Pack of 1)',
#   'oprice': '$20.25'},
#  {'brand': None,
#   'title': 'SQL Queries 2012 Joes 2 Pros 5 Volume (DVD) Certification Training Tutorial for Microsoft Exam 70-461  ',
#   'price': None,
#   'rating': 'No reviews',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Solgar Quercetin Complex with Ester-C Plus, 100 Vegetable Capsules - Supports Immune Health, Antioxidant - Gentle on the Stomach Vitamin C - Non-GMO, Vegan, Gluten / Dairy Free - 50 Servings  ',
#   'price': None,
#   'rating': '100 Count (Pack of 1)',
#   'oprice': None},
#  {'brand': None,
#   'title': 'SQL Server 2022 Query Performance Tuning: Troubleshoot and Optimize Query Performance  ',
#   'price': '54.',
#   'rating': 'by ',
#   'oprice': '$54.64'},
#  {'brand': None,
#   'title': 'Pee Wee Serial Killer or Homicidal Maniac: A Novelized True Crime Story, Volume I  ',
#   'price': '2.',
#   'rating': 'by ',
#   'oprice': '$2.99'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': ' or ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': 'Price and other details may vary based on product size and color.',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Quaker Queries for All Seasons  ',
#   'price': '9.',
#   'rating': 'by ',
#   'oprice': '$9.99'},
#  {'brand': None,
#   'title': "Cosmic Queries: StarTalk's Guide to Who We Are, How We Got Here, and Where We're Going  ",
#   'price': '22.',
#   'rating': 'by ',
#   'oprice': '$22.49'},
#  {'brand': None,
#   'title': 'SQL Queries for Mere Mortals: A Hands-On Guide to Data Manipulation in SQL  ',
#   'price': '40.',
#   'rating': '4.5',
#   'oprice': '$40.99'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': 'Old Country  ',
#   'price': '0.',
#   'rating': 'by ',
#   'oprice': '$0.00'},
#  {'brand': None,
#   'title': 'EXCEL 2022 POWER PIVOT & POWER QUERY FOR BEGINNERS: COMPLETE STEP-BY-STEP PRACTICAL GUIDE WITH EXAMPLES FOR MASTERING EXCEL POWER PIVOT AND POWER ... IMPORTATION, TRANSFORMATION, AND MODELLING  ',
#   'price': '12.',
#   'rating': '3.5',
#   'oprice': '$12.99'},
#  {'brand': None,
#   'title': 'SQL Cookbook: Query Solutions and Techniques for All SQL Users  ',
#   'price': '24.',
#   'rating': 'by ',
#   'oprice': '$24.96'},
#  {'brand': None,
#   'title': 'The Failsafe Query: The high risk search for a spy legacy (Failsafe Thrillers)  ',
#   'price': '9.',
#   'rating': '4.0',
#   'oprice': '$9.08'},
#  {'brand': None,
#   'title': 'Query: Everything You Need To Get Started, Get Noticed, and Get Signed  ',
#   'price': '3.',
#   'rating': 'by ',
#   'oprice': '$3.99'},
#  {'brand': None,
#   'title': 'Quarrys, Queries  ',
#   'price': None,
#   'rating': 'by ',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Easy Sim USSD, Query, Recharge  ',
#   'price': None,
#   'rating': 'Nov 13, 2016',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': 'The Big Book Of SQL Queries: 250+ SQL Practice Queries (SQL Series)  ',
#   'price': '24.',
#   'rating': '4.6',
#   'oprice': '$24.95'},
#  {'brand': None,
#   'title': 'SQL Server 2017 Query Performance Tuning: Troubleshoot and Optimize Query Performance  ',
#   'price': '38.',
#   'rating': 'by ',
#   'oprice': '$38.03'},
#  {'brand': None,
#   'title': 'Jackery Portable Power Station Explorer 240, 240Wh Backup Lithium Battery, 110V/200W Pure Sine Wave AC Outlet, Solar Generator (Solar Panel Not Included) for Outdoors Camping Travel Hunting Emergency  ',
#   'price': None,
#   'rating': '4.7',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Query  ',
#   'price': '0.',
#   'rating': '2020',
#   'oprice': '$0.99'},
#  {'brand': None,
#   'title': 'Milwaukee 48-11-1880 M18 REDLITHIUM HIGH OUTPUT 18v 8.0 Ah Lithium-Ion Battery Pack  ',
#   'price': '118.',
#   'rating': '4.8',
#   'oprice': '$118.00'},
#  {'brand': None,
#   'title': 'Betsey Johnson Woven Mixed Multi-Colored Bead Flower Heart Illusion Necklace  ',
#   'price': '48.',
#   'rating': '4.4',
#   'oprice': '$48.00'},
#  {'brand': None,
#   'title': 'DEWALT 20V MAX Battery, 2 Ah and 4 Ah, 4-Pack, Fuel Gauge LED Charge Indicators(DCB324-4)  ',
#   'price': '172.',
#   'rating': '4.8',
#   'oprice': '$172.99'},
#  {'brand': None,
#   'title': 'Thorne Quercetin Phytosome - Exclusive Phytosome Complex for Immune Health, Respiratory Support, and Seasonal Allergy Relief - 60 Capsules  ',
#   'price': '37.',
#   'rating': '60 Count (Pack of 1)',
#   'oprice': '$37.98'},
#  {'brand': None,
#   'title': 'Live Nude Girls Unite!  ',
#   'price': '3.',
#   'rating': '2000',
#   'oprice': '$3.99'},
#  {'brand': None,
#   'title': 'Milwaukee M18 48-11-1850 5.0 AH Batteries 5.0 18V 48-11-1852 (2 pack)  ',
#   'price': None,
#   'rating': '4.7',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Energizer 2032 Batteries, Lithium CR2032 Watch Battery, 6 Count  ',
#   'price': None,
#   'rating': '6 Count (Pack of 1)',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Adobe Acrobat Professional DC | Create, edit and sign PDF documents | 1-month Subscription with auto-renewal, PC/Mac  ',
#   'price': '24.',
#   'rating': '3.9',
#   'oprice': '$24.99'},
#  {'brand': None,
#   'title': 'DEWALT 20V MAX XR Battery, Lithium Ion, 5.0Ah (DCB205)  ',
#   'price': '70.',
#   'rating': '4.7',
#   'oprice': '$70.95'},
#  {'brand': None,
#   'title': 'NOW Supplements, Quercetin with Bromelain, Balanced Immune System*, 120 Veg Capsules  ',
#   'price': '15.',
#   'rating': '4.7',
#   'oprice': '$15.11'},
#  {'brand': None,
#   'title': 'Amazing Formulas Quercetin 500mg 120 Veggie Capsules Supplement - Non-GMO - Gluten Free - Supports Overall Health & Well Being  ',
#   'price': '19.',
#   'rating': '120 Count (Pack of 1)',
#   'oprice': '$19.99'},
#  {'brand': None,
#   'title': 'Jarrow Formulas Quercetin 500 mg - Supports Antioxidant Status, Cardiovascular Health & Immune Health - Dietary Supplement - 100 Servings (Veggie Caps) (Packaging May Vary)  ',
#   'price': '22.',
#   'rating': '100 Count (Pack of 1)',
#   'oprice': '$22.77'},
#  {'brand': None,
#   'title': 'Creating a Query with Microsoft Access 2007  ',
#   'price': None,
#   'rating': '2017',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Milwaukee 48-11-1850 M18 Redlithium 5.0Ah Bat Pack  ',
#   'price': '61.',
#   'rating': '4.8',
#   'oprice': '$61.99'},
#  {'brand': None,
#   'title': 'Energizer 2032 Batteries, Lithium CR2032 Watch Battery, 4 Count  ',
#   'price': None,
#   'rating': '4 Count (Pack of 1)',
#   'oprice': None},
#  {'brand': None,
#   'title': 'NatureBell Quercetin 1000mg Per Serving | 240 Capsules, Ultra Strength Quercetin Supplement | Bioflavonoids for Healthy Immune Support, Third Party Tested, Non-GMO & No Gluten  ',
#   'price': '26.',
#   'rating': '240 Count (Pack of 1)',
#   'oprice': '$26.95'},
#  {'brand': None,
#   'title': 'Zinc Quercetin 120 Vegetarian Capsules  ',
#   'price': '24.',
#   'rating': '120 Count (Pack of 1)',
#   'oprice': '$24.95'},
#  {'brand': None,
#   'title': 'SOLARAY Quercetin 500 mg, Supports Sinus, Respiratory, Immune Function & Normal, Healthy Uric Acid Levels, 90 VegCaps  ',
#   'price': '23.',
#   'rating': '90 Count (Pack of 1)',
#   'oprice': '$23.39'},
#  {'brand': None,
#   'title': 'SVP‑916 100‑130VAC Adjustable Over and Under Voltage Protector, Delay Reset Protector, with Reset Mode Selection, Fault Query and Factory Reset Function  ',
#   'price': '17.',
#   'rating': '4.5',
#   'oprice': '$17.20'},
#  {'brand': None,
#   'title': 'Query Craft: The Writer-in-the-Know Guide to Getting Your Manuscript Requested  ',
#   'price': '11.',
#   'rating': 'by ',
#   'oprice': '$11.99'},
#  {'brand': None,
#   'title': "Doctor's Best Quercetin Bromelain, Immunity Support, Heart, Joint & Healthy Respiratory System, Non-GMO, Vegan, Gluten Free, Soy Free,180 VC  ",
#   'price': '21.',
#   'rating': '180 Count (Pack of 1)',
#   'oprice': '$21.68'},
#  {'brand': None,
#   'title': '8.4 - 2. Working with Media Queries  ',
#   'price': None,
#   'rating': '2017',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Duracell CR2032 3V Lithium Battery, Child Safety Features, 6 Count Pack, Lithium Coin Battery for Key Fob, Car Remote, Glucose Monitor, CR Lithium 3 Volt Cell  ',
#   'price': None,
#   'rating': '6 Count (Pack of 1)',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Master Your Data with Power Query in Excel and Power BI: Leveraging Power Query to Get & Transform Your Task Flow  ',
#   'price': '19.',
#   'rating': 'by ',
#   'oprice': '$19.39'},
#  {'brand': None,
#   'title': 'Excel Power Pivot & Power Query For Dummies  ',
#   'price': '25.',
#   'rating': 'by ',
#   'oprice': '$25.49'},
#  {'brand': None,
#   'title': 'Optima Batteries 8004-003 34/78 RedTop Starting Battery  ',
#   'price': None,
#   'rating': '4.5',
#   'oprice': None},
#  {'brand': None,
#   'title': 'The Ultimate Guide to Power Query: A Step-By-Step Guide on Using Power Query Effectively for Data Transformation  ',
#   'price': '12.',
#   'rating': 'by ',
#   'oprice': '$12.00'},
#  {'brand': None,
#   'title': 'Starry Messenger: Cosmic Perspectives on Civilization  ',
#   'price': '0.',
#   'rating': 'by ',
#   'oprice': '$0.00'},
#  {'brand': None,
#   'title': 'Quercetin | Sugar Free | Liquid Quercetin 500mg Immune Support for Adults & Kids | Inflammation Support Supplement | Immune Defense | Cellular Health | Vegan | Non-GMO | Gluten Free | 4 Fl Oz  ',
#   'price': '20.',
#   'rating': '4 Fl Oz (Pack of 1)',
#   'oprice': '$20.25'},
#  {'brand': None,
#   'title': 'SQL Server 2022 Query Performance Tuning: Troubleshoot and Optimize Query Performance  ',
#   'price': '54.',
#   'rating': 'by ',
#   'oprice': '$54.64'},
#  {'brand': None,
#   'title': 'Solgar Quercetin Complex with Ester-C Plus, 100 Vegetable Capsules - Supports Immune Health, Antioxidant - Gentle on the Stomach Vitamin C - Non-GMO, Vegan, Gluten / Dairy Free - 50 Servings  ',
#   'price': None,
#   'rating': '100 Count (Pack of 1)',
#   'oprice': None},
#  {'brand': None,
#   'title': 'SQL Queries 2012 Joes 2 Pros 5 Volume (DVD) Certification Training Tutorial for Microsoft Exam 70-461  ',
#   'price': None,
#   'rating': 'No reviews',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Collect, Combine, and Transform Data Using Power Query in Excel and Power BI (Business Skills)  ',
#   'price': '36.',
#   'rating': '4.6',
#   'oprice': '$36.53'},
#  {'brand': None,
#   'title': 'Amazon Basics 4 Pack CR2032 3 Volt Lithium Coin Cell Battery  ',
#   'price': None,
#   'rating': '4.7',
#   'oprice': None},
#  {'brand': None,
#   'title': 'Learn SQL in a weekend: The definitive guide for creating and querying databases  ',
#   'price': '8.',
#   'rating': '4.4',
#   'oprice': '$8.99'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': ' or ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None}]

# %%
import pandas as pd
pd.DataFrame(all_data).dropna(how='any').to_excel('amazon.xlsx',index=False)
